# %% [markdown]
# ## Installing FER

# %%
# !pip install fer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 28.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 58.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=f92e2dfcea88287722a3d81b80788e50bfbff7c934efdf7718cf344c09f8df21
#   Stored in directory: /root/.cache/pip/wheels/8e/7a/69/cd6aeb83b126a7f04cbe7c9d929028dc52a6e7d525ff56003a
# Successfully built ffmpeg
# ...

# %% [markdown]
# ## Importing FER and cv2

# %%
from fer import FER
import cv2

# %% [markdown]
# ## Setting up FER

# %%
emotion_detector = FER(mtcnn=True)

# %% [markdown]
# ## Import from drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Multiple faces detection

# %%
friends = '/content/gdrive/MyDrive/EmotionDetector/friends show.jpg'

# %% [markdown]
# ![friends-ss2_0.jpg](data:image/jpeg;base64,...)

# %%
friends_img= cv2.imread(friends)
analysis = emotion_detector.detect_emotions(friends_img)
analysis
# Out:
# [{'box': [104, 32, 45, 59],
#   'emotions': {'angry': 0.41,
#    'disgust': 0.0,
#    'fear': 0.13,
#    'happy': 0.04,
#    'sad': 0.13,
#    'surprise': 0.03,
#    'neutral': 0.25}},
#  {'box': [188, 80, 37, 47],
#   'emotions': {'angry': 0.0,
#    'disgust': 0.0,
#    'fear': 0.0,
#    'happy': 1.0,
#    'sad': 0.0,
#    'surprise': 0.0,
#    'neutral': 0.0}},
#  {'box': [286, 82, 26, 32],
#   'emotions': {'angry': 0.48,
#    'disgust': 0.0,
#    'fear': 0.08,
#    'happy': 0.04,
#    'sad': 0.33,
#    'surprise': 0.0,
#    'neutral': 0.07}},
#  {'box': [234, 99, 22, 32],
#   'emotions': {'angry': 0.16,
#    'disgust': 0.0,
#    'fear': 0.23,
#    'happy': 0.03,
#    'sad': 0.48,
#    'surprise': 0.01,
#    'neutral': 0.08}}]

# %% [markdown]
# ## Single face detection

# %%
joey = '/content/gdrive/MyDrive/EmotionDetector/joey.jpg'

# %% [markdown]
# ![friends-trivia-18-matt-leblanc-aka-joey-tribbiani-auditioned-with-just-11-got-himself-this-after-his-first-paycheck-001.jpg](data:image/jpeg;base64,...)

# %%
joey_img= cv2.imread(joey)
analysis = emotion_detector.detect_emotions(joey_img)
analysis
# Out:
# [{'box': [234, 64, 142, 188],
#   'emotions': {'angry': 0.0,
#    'disgust': 0.0,
#    'fear': 0.0,
#    'happy': 1.0,
#    'sad': 0.0,
#    'surprise': 0.0,
#    'neutral': 0.0}}]

# %%
dominant_emotion, emotion_score = emotion_detector.top_emotion(joey_img)
print(dominant_emotion, emotion_score)
# Out:
# happy 1.0
